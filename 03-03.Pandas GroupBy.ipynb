# %% [markdown]
# <a href="https://colab.research.google.com/github/Yiting916/data_analysis/blob/main/03-03.Pandas%20GroupBy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GroupBy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("/content/drive/MyDrive/YiTing/Learning/Python/資料分析技術/data/vgsales.csv")
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data.groupby('Genre')

# %%
data.groupby('Genre').size()
# Out:
# Genre
# Action          3316
# Adventure       1286
# Fighting         848
# Misc            1739
# Platform         886
# Puzzle           582
# Racing          1249
# Role-Playing    1488
# Shooter         1310
# Simulation       867
# Sports          2346
# Strategy         681
# dtype: int64

# %%
data.groupby(['Year','Platform']).size()
# Out:
# Year    Platform
# 1980.0  2600         9
# 1981.0  2600        46
# 1982.0  2600        36
# 1983.0  2600        11
#         NES          6
#                     ..
# 2016.0  X360         8
#         XOne        54
# 2017.0  PS4          1
#         PSV          2
# 2020.0  DS           1
# Length: 241, dtype: int64

# %%
data.groupby(['Year','Platform']).sum()
# Out:
#                    Rank                                               Name  \
# Year   Platform
# 1980.0 2600       29826  AsteroidsMissile CommandKaboom!DefenderBoxingI...
# 1981.0 2600      190488  Pitfall!FroggerDemon AttackE.T.: The Extra Ter...
# 1982.0 2600      149186  Pac-ManDig DugMario Bros.Pole PositionMoon Pat...
# 1983.0 2600       49355  Pitfall II: Lost CavernsJr. Pac-ManCrystal Cas...
#        NES         7404  BaseballMario Bros.MahjongDonkey KongDonkey Ko...
# ...                 ...                                                ...
# 2016.0 X360       93657  LEGO Marvel's AvengersFIFA 17Lego Star Wars: T...
#        XOne      584548  Tom Clancy's The DivisionFIFA 17Far Cry: Prima...
# 2017.0 PS4        14393   Phantasy Star Online 2 Episode 4: Deluxe Package
#        PSV        32685  Phantasy Star Online 2 Episode 4: Deluxe Packa...
# 2020.0 DS          5959                             Imagine: Makeup Artist
#
#                                                              Genre  \
# Year   Platform
# 1980.0 2600      ShooterShooterMiscMiscFightingSportsActionMisc...
# 1981.0 2600      PlatformActionShooterActionPuzzleShooterPlatfo...
# 1982.0 2600      PuzzlePuzzlePlatformRacingShooterPlatformPlatf...
# 1983.0 2600      PlatformPuzzleActionActionShooterActionAdventu...
#        NES              SportsPlatformMiscPlatformPlatformPlatform
# ...                                                            ...
# 2016.0 X360      ActionSportsActionSportsSportsActionSportsShooter
#        XOne      ShooterSportsActionShooterSportsShooterSportsA...
# 2017.0 PS4                                            Role-Playing
#        PSV                                      Role-PlayingAction
# 2020.0 DS                                               Simulation
#
#                                                          Publisher  NA_Sales  \
# Year   Platform
# 1980.0 2600      AtariAtariActivisionAtariActivisionActivisionA...     10.59
# 1981.0 2600      ActivisionParker Bros.ImagicAtariAtariActivisi...     33.40
# 1982.0 2600      AtariAtariAtariAtariAtariAtariAtariQuelleAtari...     26.92
# 1983.0 2600      ActivisionAtariAtariAtariAtariAtariAtariActivi...      5.44
#        NES        NintendoNintendoNintendoNintendoNintendoNintendo      2.32
# ...                                                            ...       ...
# 2016.0 X360      Warner Bros. Interactive EntertainmentElectron...      0.36
#        XOne      UbisoftElectronic ArtsUbisoftActivisionElectro...      6.69
# 2017.0 PS4                                                    Sega      0.00
#        PSV                                        SegaIdea Factory      0.00
# 2020.0 DS                                                  Ubisoft      0.27
#
#                  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year   Platform
# 1980.0 2600          0.67      0.00         0.12         11.38
# 1981.0 2600          1.96      0.00         0.32         35.77
# 1982.0 2600          1.65      0.00         0.31         28.86
# 1983.0 2600          0.34      0.00         0.06          5.83
#        NES           0.46      8.10         0.08         10.96
# ...                   ...       ...          ...           ...
# 2016.0 X360          0.40      0.00         0.07          0.83
#        XOne          4.63      0.01         1.05         12.37
# 2017.0 PS4           0.00      0.03         0.00          0.03
#        PSV           0.00      0.02         0.00          0.02
# 2020.0 DS            0.00      0.00         0.02          0.29
#
# [241 rows x 9 columns]

# %%
keys = ['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']
data.groupby(['Year','Platform'])[keys].sum()
# Out:
#                  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year   Platform
# 1980.0 2600         10.59      0.67      0.00         0.12         11.38
# 1981.0 2600         33.40      1.96      0.00         0.32         35.77
# 1982.0 2600         26.92      1.65      0.00         0.31         28.86
# 1983.0 2600          5.44      0.34      0.00         0.06          5.83
#        NES           2.32      0.46      8.10         0.08         10.96
# ...                   ...       ...       ...          ...           ...
# 2016.0 X360          0.36      0.40      0.00         0.07          0.83
#        XOne          6.69      4.63      0.01         1.05         12.37
# 2017.0 PS4           0.00      0.00      0.03         0.00          0.03
#        PSV           0.00      0.00      0.02         0.00          0.02
# 2020.0 DS            0.27      0.00      0.00         0.02          0.29
#
# [241 rows x 5 columns]

# %%
keys = ["NA_Sales",	"EU_Sales",	"JP_Sales",	"Other_Sales",	"Global_Sales"]
data.groupby(["Genre"])[keys].mean()
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action        0.264726  0.158323  0.048236     0.056508      0.528100
# Adventure     0.082271  0.049868  0.040490     0.013072      0.185879
# Fighting      0.263667  0.119481  0.103007     0.043255      0.529375
# Misc          0.235906  0.124198  0.061967     0.043312      0.465762
# Platform      0.504571  0.227573  0.147596     0.058228      0.938341
# Puzzle        0.212680  0.087251  0.098471     0.021564      0.420876
# Racing        0.287766  0.190865  0.045388     0.061865      0.586101
# Role-Playing  0.219946  0.126384  0.236767     0.040060      0.623233
# Shooter       0.444733  0.239137  0.029221     0.078389      0.791885
# Simulation    0.211430  0.130773  0.073472     0.036355      0.452364
# Sports        0.291283  0.160635  0.057702     0.057532      0.567319
# Strategy      0.100881  0.066579  0.072628     0.016681      0.257151

# %%
data.groupby(['Year','Platform']).sum().reset_index()
# Out:
#        Year Platform    Rank  \
# 0    1980.0     2600   29826
# 1    1981.0     2600  190488
# 2    1982.0     2600  149186
# 3    1983.0     2600   49355
# 4    1983.0      NES    7404
# ..      ...      ...     ...
# 236  2016.0     X360   93657
# 237  2016.0     XOne  584548
# 238  2017.0      PS4   14393
# 239  2017.0      PSV   32685
# 240  2020.0       DS    5959
#
#                                                   Name  \
# 0    AsteroidsMissile CommandKaboom!DefenderBoxingI...
# 1    Pitfall!FroggerDemon AttackE.T.: The Extra Ter...
# 2    Pac-ManDig DugMario Bros.Pole PositionMoon Pat...
# 3    Pitfall II: Lost CavernsJr. Pac-ManCrystal Cas...
# 4    BaseballMario Bros.MahjongDonkey KongDonkey Ko...
# ..                                                 ...
# 236  LEGO Marvel's AvengersFIFA 17Lego Star Wars: T...
# 237  Tom Clancy's The DivisionFIFA 17Far Cry: Prima...
# 238   Phantasy Star Online 2 Episode 4: Deluxe Package
# 239  Phantasy Star Online 2 Episode 4: Deluxe Packa...
# 240                             Imagine: Makeup Artist
#
#                                                  Genre  \
# 0    ShooterShooterMiscMiscFightingSportsActionMisc...
# 1    PlatformActionShooterActionPuzzleShooterPlatfo...
# 2    PuzzlePuzzlePlatformRacingShooterPlatformPlatf...
# 3    PlatformPuzzleActionActionShooterActionAdventu...
# 4           SportsPlatformMiscPlatformPlatformPlatform
# ..                                                 ...
# 236  ActionSportsActionSportsSportsActionSportsShooter
# 237  ShooterSportsActionShooterSportsShooterSportsA...
# 238                                       Role-Playing
# 239                                 Role-PlayingAction
# 240                                         Simulation
#
#                                              Publisher  NA_Sales  EU_Sales  \
# 0    AtariAtariActivisionAtariActivisionActivisionA...     10.59      0.67
# 1    ActivisionParker Bros.ImagicAtariAtariActivisi...     33.40      1.96
# 2    AtariAtariAtariAtariAtariAtariAtariQuelleAtari...     26.92      1.65
# 3    ActivisionAtariAtariAtariAtariAtariAtariActivi...      5.44      0.34
# 4     NintendoNintendoNintendoNintendoNintendoNintendo      2.32      0.46
# ..                                                 ...       ...       ...
# 236  Warner Bros. Interactive EntertainmentElectron...      0.36      0.40
# 237  UbisoftElectronic ArtsUbisoftActivisionElectro...      6.69      4.63
# 238                                               Sega      0.00      0.00
# 239                                   SegaIdea Factory      0.00      0.00
# 240                                            Ubisoft      0.27      0.00
#
#      JP_Sales  Other_Sales  Global_Sales
# 0        0.00         0.12         11.38
# 1        0.00         0.32         35.77
# 2        0.00         0.31         28.86
# 3        0.00         0.06          5.83
# 4        8.10         0.08         10.96
# ..        ...          ...           ...
# 236      0.00         0.07          0.83
# 237      0.01         1.05         12.37
# 238      0.03         0.00          0.03
# 239      0.02         0.00          0.02
# 240      0.00         0.02          0.29
#
# [241 rows x 11 columns]

# %%
data.groupby('Platform').get_group('Wii')
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#          Year     Genre                     Publisher  NA_Sales  EU_Sales  \
# 0      2006.0    Sports                      Nintendo     41.49     29.02
# 2      2008.0    Racing                      Nintendo     15.85     12.88
# 3      2009.0    Sports                      Nintendo     15.75     11.01
# 7      2006.0      Misc                      Nintendo     14.03      9.20
# 8      2009.0  Platform                      Nintendo     14.59      7.06
# ...       ...       ...                           ...       ...       ...
# 16517  2007.0    Action  Konami Digital Entertainment      0.00      0.01
# 16552  2007.0  Fighting         Marvelous Interactive      0.00      0.00
# 16573  2007.0    Racing                Popcorn Arcade      0.01      0.00
# 16574  2008.0    Racing                   Takara Tomy      0.00      0.00
# 16581  2011.0    Sports                       Unknown      0.00      0.01
#
#        JP_Sales  Other_Sales  Global_Sales
# 0          3.77         8.46         82.74
# 2          3.79         3.31         35.82
# 3          3.28         2.96         33.00
# 7          2.93         2.85         29.02
# 8          4.70         2.26         28.62
# ...         ...          ...           ...
# 16517      0.00         0.00          0.01
# 16552      0.01         0.00          0.01
# 16573      0.00         0.00          0.01
# 16574      0.01         0.00          0.01
# 16581      0.00         0.00          0.01
#
# [1325 rows x 11 columns]

# %%
# data.groupby('Platform').get_group('Wii')
# 等同於
data[data['Platform'] == 'Wii']
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#          Year     Genre                     Publisher  NA_Sales  EU_Sales  \
# 0      2006.0    Sports                      Nintendo     41.49     29.02
# 2      2008.0    Racing                      Nintendo     15.85     12.88
# 3      2009.0    Sports                      Nintendo     15.75     11.01
# 7      2006.0      Misc                      Nintendo     14.03      9.20
# 8      2009.0  Platform                      Nintendo     14.59      7.06
# ...       ...       ...                           ...       ...       ...
# 16517  2007.0    Action  Konami Digital Entertainment      0.00      0.01
# 16552  2007.0  Fighting         Marvelous Interactive      0.00      0.00
# 16573  2007.0    Racing                Popcorn Arcade      0.01      0.00
# 16574  2008.0    Racing                   Takara Tomy      0.00      0.00
# 16581  2011.0    Sports                       Unknown      0.00      0.01
#
#        JP_Sales  Other_Sales  Global_Sales
# 0          3.77         8.46         82.74
# 2          3.79         3.31         35.82
# 3          3.28         2.96         33.00
# 7          2.93         2.85         29.02
# 8          4.70         2.26         28.62
# ...         ...          ...           ...
# 16517      0.00         0.00          0.01
# 16552      0.01         0.00          0.01
# 16573      0.00         0.00          0.01
# 16574      0.01         0.00          0.01
# 16581      0.00         0.00          0.01
#
# [1325 rows x 11 columns]

# %%
# 預設會忽略Nan，可以加上 dropna=False 來強制不忽略
data.groupby('Year',dropna=False).size()
# Out:
# Year
# 1980.0       9
# 1981.0      46
# 1982.0      36
# 1983.0      17
# 1984.0      14
# 1985.0      14
# 1986.0      21
# 1987.0      16
# 1988.0      15
# 1989.0      17
# 1990.0      16
# 1991.0      41
# 1992.0      43
# 1993.0      60
# 1994.0     121
# 1995.0     219
# 1996.0     263
# 1997.0     289
# 1998.0     379
# 1999.0     338
# 2000.0     349
# 2001.0     482
# 2002.0     829
# 2003.0     775
# 2004.0     763
# 2005.0     941
# 2006.0    1008
# 2007.0    1202
# 2008.0    1428
# 2009.0    1431
# 2010.0    1259
# 2011.0    1139
# 2012.0     657
# 2013.0     546
# 2014.0     582
# 2015.0     614
# 2016.0     344
# 2017.0       3
# 2020.0       1
# NaN        271
# dtype: int64

# %%
# 取得 group 後每一群資料的 index
x = data.groupby('Year').groups # groups 為屬性
idx = x[2007.0]
data.iloc[idx]
# Out:
#         Rank                                               Name Platform  \
# 13        14                                            Wii Fit      Wii
# 43        44                                             Halo 3     X360
# 48        49                                 Super Mario Galaxy      Wii
# 70        71                     Call of Duty 4: Modern Warfare     X360
# 74        75                                     Mario Party DS       DS
# ...      ...                                                ...      ...
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16558  16561                          Pro Evolution Soccer 2008       PC
# 16564  16567      Original Frisbee Disc Sports: Ultimate & Golf       DS
# 16573  16576                                Mini Desktop Racing      Wii
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 13     2007.0        Sports                      Nintendo      8.94      8.03
# 43     2007.0       Shooter        Microsoft Game Studios      7.97      2.83
# 48     2007.0      Platform                      Nintendo      6.16      3.40
# 70     2007.0       Shooter                    Activision      5.91      2.38
# 74     2007.0          Misc                      Nintendo      4.46      1.88
# ...       ...           ...                           ...       ...       ...
# 16552  2007.0      Fighting         Marvelous Interactive      0.00      0.00
# 16558  2007.0        Sports  Konami Digital Entertainment      0.00      0.01
# 16564  2007.0        Action     Destination Software, Inc      0.01      0.00
# 16573  2007.0        Racing                Popcorn Arcade      0.01      0.00
# 16590  2007.0  Role-Playing            Falcom Corporation      0.00      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 13         3.60         2.15         22.72
# 43         0.13         1.21         12.14
# 48         1.20         0.76         11.52
# 70         0.13         0.90          9.32
# 74         1.98         0.70          9.02
# ...         ...          ...           ...
# 16552      0.01         0.00          0.01
# 16558      0.00         0.00          0.01
# 16564      0.00         0.00          0.01
# 16573      0.00         0.00          0.01
# 16590      0.01         0.00          0.01
#
# [1202 rows x 11 columns]

# %%
# index = data.groupby('Platform').groups["Wii"]
# data.iloc[index]
# 等同於：
index = data["Platform"] == "Wii"
data[index]
# 也可以用：
# data.loc[index]
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#          Year     Genre                     Publisher  NA_Sales  EU_Sales  \
# 0      2006.0    Sports                      Nintendo     41.49     29.02
# 2      2008.0    Racing                      Nintendo     15.85     12.88
# 3      2009.0    Sports                      Nintendo     15.75     11.01
# 7      2006.0      Misc                      Nintendo     14.03      9.20
# 8      2009.0  Platform                      Nintendo     14.59      7.06
# ...       ...       ...                           ...       ...       ...
# 16517  2007.0    Action  Konami Digital Entertainment      0.00      0.01
# 16552  2007.0  Fighting         Marvelous Interactive      0.00      0.00
# 16573  2007.0    Racing                Popcorn Arcade      0.01      0.00
# 16574  2008.0    Racing                   Takara Tomy      0.00      0.00
# 16581  2011.0    Sports                       Unknown      0.00      0.01
#
#        JP_Sales  Other_Sales  Global_Sales
# 0          3.77         8.46         82.74
# 2          3.79         3.31         35.82
# 3          3.28         2.96         33.00
# 7          2.93         2.85         29.02
# 8          4.70         2.26         28.62
# ...         ...          ...           ...
# 16517      0.00         0.00          0.01
# 16552      0.01         0.00          0.01
# 16573      0.00         0.00          0.01
# 16574      0.01         0.00          0.01
# 16581      0.00         0.00          0.01
#
# [1325 rows x 11 columns]

# %% [markdown]
# ## Aggregation

# %%
data.groupby('Platform').sum()
# Out:
#               Rank                                               Name  \
# Platform
# 2600        585665  Pac-ManPitfall!AsteroidsMissile CommandSpace I...
# 3DO          43118  PolicenautsBust-A-MoveSotsugyou II: Neo Genera...
# 3DS        4662644  Pokemon X/Pokemon YMario Kart 7Pokemon Omega R...
# DC          456114  Sonic AdventureCrazy TaxiNFL 2KShenmueResident...
# DS        20845831  New Super Mario Bros.NintendogsMario Kart DSBr...
# GB          332419  Pokemon Red/Pokemon BlueTetrisPokemon Gold/Pok...
# GBA        7136749  Pokemon Ruby/Pokemon SapphirePokemon FireRed/P...
# GC         4817401  Super Smash Bros. MeleeMario Kart: Double Dash...
# GEN         190019  Sonic the Hedgehog 2Sonic the HedgehogMortal K...
# GG           13527                       Sonic the Hedgehog 2 (8-bit)
# N64        2083189  Super Mario 64Mario Kart 64GoldenEye 007The Le...
# NES         186831  Super Mario Bros.Duck HuntSuper Mario Bros. 3S...
# NG          127988  Samurai Shodown IIThe King of Fighters '95 (CD...
# PC        10980787  The Sims 3World of WarcraftDiablo IIIMicrosoft...
# PCFX         14559                 Blue Breaker: Ken Yorimo Hohoemi o
# PS         8322033  Gran TurismoFinal Fantasy VIIGran Turismo 2Fin...
# PS2       16159167  Grand Theft Auto: San AndreasGrand Theft Auto:...
# PS3        9027970  Grand Theft Auto VCall of Duty: Black Ops IICa...
# PS4        2562189  Call of Duty: Black Ops 3Grand Theft Auto VFIF...
# PSP       12615047  Grand Theft Auto: Liberty City StoriesMonster ...
# PSV        4732241  MinecraftUncharted: Golden AbyssCall of Duty B...
# SAT        1614771  Virtua Fighter 2Sega Rally ChampionshipVirtua ...
# SCD          61031  Sonic CDShining Force CDFormula One World Cham...
# SNES       1516804  Super Mario WorldSuper Mario All-StarsDonkey K...
# TG16         24763           DoukyuuseiGinga Fukei Densetsu: Sapphire
# WS           47273  Final FantasyDigimon Adventure: Anode TamerFin...
# Wii       10243276  Wii SportsMario Kart WiiWii Sports ResortWii P...
# WiiU       1109142  Mario Kart 8New Super Mario Bros. USuper Smash...
# X360       8466048  Kinect Adventures!Grand Theft Auto VCall of Du...
# XB         7219276  Halo 2Halo: Combat EvolvedTom Clancy's Splinte...
# XOne       1575574  Call of Duty: Black Ops 3Call of Duty: Advance...
#
#                Year                                              Genre  \
# Platform
# 2600       229928.0  PuzzlePlatformShooterShooterShooterActionShoot...
# 3DO          5984.0                          AdventurePuzzleSimulation
# 3DS       1006531.0  Role-PlayingRacingRole-PlayingPlatformPlatform...
# DC         103997.0  PlatformRacingSportsAdventureActionSportsSimul...
# DS        4283493.0  PlatformSimulationRacingMiscRole-PlayingRole-P...
# GB         193608.0  Role-PlayingPuzzleRole-PlayingPlatformRole-Pla...
# GBA       1624604.0  Role-PlayingRole-PlayingRole-PlayingPlatformRa...
# GC        1085843.0  FightingRacingPlatformActionActionSimulationSh...
# GEN         53812.0  PlatformPlatformFightingActionSportsPlatformPl...
# GG           1992.0                                           Platform
# N64        631536.0  PlatformRacingShooterActionFightingStrategyPla...
# NES        194741.0  PlatformShooterPlatformPlatformActionPuzzlePuz...
# NG          23934.0  FightingFightingFightingFightingFightingFighti...
# PC        1894273.0  SimulationRole-PlayingRole-PlayingSimulationSt...
# PCFX         1996.0                                       Role-Playing
# PS        2375627.0  RacingRole-PlayingRacingRole-PlayingPlatformFi...
# PS2       4263750.0  ActionActionRacingActionRacingRole-PlayingRaci...
# PS3       2622109.0  ActionShooterShooterShooterRacingShooterAction...
# PS4        677042.0  ShooterActionSportsShooterShooterRole-PlayingS...
# PSP       2404440.0  ActionRole-PlayingActionRole-PlayingPlatformPl...
# PSV        829782.0  MiscShooterActionActionPlatformRole-PlayingRac...
# SAT        345313.0  FightingRacingFightingShooterFightingPuzzleRac...
# SCD         11963.0         PlatformStrategyRacingRole-PlayingMiscMisc
# SNES       476529.0  PlatformPlatformPlatformRacingFightingPlatform...
# TG16         3990.0                                   AdventureShooter
# WS          12000.0  Role-PlayingRole-PlayingRole-PlayingRole-Playi...
# Wii       2591562.0  SportsRacingSportsMiscPlatformSportsSportsFigh...
# WiiU       287944.0  RacingPlatformFightingShooterMiscPlatformPlatf...
# X360      2482205.0  MiscActionShooterShooterShooterShooterShooterA...
# XB        1608920.0  ShooterShooterActionRole-PlayingRole-PlayingAc...
# XOne       429150.0  ShooterShooterActionShooterRole-PlayingShooter...
#
#                                                   Publisher  NA_Sales  \
# Platform
# 2600      AtariActivisionAtariAtariAtariParker Bros.Imag...     90.60
# 3DO       Konami Digital EntertainmentMicro CabinImageworks      0.00
# 3DS       NintendoNintendoNintendoNintendoNintendoNinten...     78.87
# DC        SegaSegaSegaSegaEidos InteractiveSegaSegaSegaS...      5.43
# DS        NintendoNintendoNintendoNintendoNintendoNinten...    390.71
# GB        NintendoNintendoNintendoNintendoNintendoNinten...    114.32
# GBA       NintendoNintendoNintendoNintendoNintendoNinten...    187.54
# GC        NintendoNintendoNintendoNintendoNintendoNinten...    133.46
# GEN       SegaSegaArena EntertainmentSegaArena Entertain...     19.27
# GG                                                     Sega      0.00
# N64       NintendoNintendoNintendoNintendoNintendoNinten...    139.02
# NES       NintendoNintendoNintendoNintendoNintendoNinten...    125.94
# NG        SNKSNKSNKSNKSNKSNKSNKSNKSNKSNKHudson SoftTechn...      0.00
# PC        Electronic ArtsActivisionActivisionMicrosoft G...     93.28
# PCFX                                                    NEC      0.00
# PS        Sony Computer EntertainmentSony Computer Enter...    336.51
# PS2       Take-Two InteractiveTake-Two InteractiveSony C...    583.84
# PS3       Take-Two InteractiveActivisionActivisionActivi...    392.26
# PS4       ActivisionTake-Two InteractiveElectronic ArtsE...     96.80
# PSP       Take-Two InteractiveCapcomTake-Two Interactive...    108.99
# PSV       Sony Computer Entertainment EuropeSony Compute...     16.20
# SAT       SegaSegaSegaSegaSegaCompileSegaSegaBanprestoBa...      0.72
# SCD                                SegaSegaSegaSegaSegaSega      1.00
# SNES      NintendoNintendoNintendoNintendoCapcomNintendo...     61.23
# TG16                                         NECHudson Soft      0.00
# WS        SquareSoftNamco Bandai GamesSquareSoftNamco Ba...      0.00
# Wii       NintendoNintendoNintendoNintendoNintendoNinten...    507.71
# WiiU      NintendoNintendoNintendoNintendoNintendoNinten...     38.32
# X360      Microsoft Game StudiosTake-Two InteractiveActi...    601.05
# XB        Microsoft Game StudiosMicrosoft Game StudiosUb...    186.69
# XOne      ActivisionActivisionTake-Two InteractiveMicros...     83.19
#
#           EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# 2600          5.47      0.00         0.91         97.08
# 3DO           0.00      0.10         0.00          0.10
# 3DS          58.52     97.35        12.63        247.46
# DC            1.69      8.56         0.27         15.97
# DS          194.65    175.57        60.53        822.49
# GB           47.82     85.12         8.20        255.45
# GBA          75.25     47.33         7.73        318.50
# GC           38.71     21.58         5.18        199.36
# GEN           5.52      2.67         0.89         28.36
# GG            0.00      0.04         0.00          0.04
# N64          41.06     34.22         4.38        218.88
# NES          21.15     98.65         5.31        251.07
# NG            0.00      1.44         0.00          1.44
# PC          139.68      0.17        24.86        258.82
# PCFX          0.00      0.03         0.00          0.03
# PS          213.60    139.82        40.91        730.66
# PS2         339.29    139.20       193.44       1255.64
# PS3         343.71     79.99       141.93        957.84
# PS4         123.70     14.30        43.36        278.10
# PSP          68.25     76.79        42.19        296.28
# PSV          16.33     20.96         8.45         61.93
# SAT           0.54     32.26         0.07         33.59
# SCD           0.36      0.45         0.05          1.87
# SNES         19.04    116.55         3.22        200.05
# TG16          0.00      0.16         0.00          0.16
# WS            0.00      1.42         0.00          1.42
# Wii         268.38     69.35        80.61        926.71
# WiiU         24.23     12.79         6.45         81.86
# X360        280.58     12.43        85.54        979.96
# XB           60.95      1.38         8.72        258.26
# XOne         45.65      0.34        11.92        141.06

# %%
# aggregate 裡面放自己寫的 function
data.groupby('Platform').aggregate(np.sum)
# Out:
# <ipython-input-39-4ec5ba9345a7>:1: FutureWarning: The provided callable <function sum at 0x7a2006937ce0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   data.groupby('Platform').aggregate(np.sum)
#               Rank                                               Name  \
# Platform
# 2600        585665  Pac-ManPitfall!AsteroidsMissile CommandSpace I...
# 3DO          43118  PolicenautsBust-A-MoveSotsugyou II: Neo Genera...
# 3DS        4662644  Pokemon X/Pokemon YMario Kart 7Pokemon Omega R...
# DC          456114  Sonic AdventureCrazy TaxiNFL 2KShenmueResident...
# DS        20845831  New Super Mario Bros.NintendogsMario Kart DSBr...
# GB          332419  Pokemon Red/Pokemon BlueTetrisPokemon Gold/Pok...
# GBA        7136749  Pokemon Ruby/Pokemon SapphirePokemon FireRed/P...
# GC         4817401  Super Smash Bros. MeleeMario Kart: Double Dash...
# GEN         190019  Sonic the Hedgehog 2Sonic the HedgehogMortal K...
# GG           13527                       Sonic the Hedgehog 2 (8-bit)
# N64        2083189  Super Mario 64Mario Kart 64GoldenEye 007The Le...
# NES         186831  Super Mario Bros.Duck HuntSuper Mario Bros. 3S...
# NG          127988  Samurai Shodown IIThe King of Fighters '95 (CD...
# PC        10980787  The Sims 3World of WarcraftDiablo IIIMicrosoft...
# PCFX         14559                 Blue Breaker: Ken Yorimo Hohoemi o
# PS         8322033  Gran TurismoFinal Fantasy VIIGran Turismo 2Fin...
# PS2       16159167  Grand Theft Auto: San AndreasGrand Theft Auto:...
# PS3        9027970  Grand Theft Auto VCall of Duty: Black Ops IICa...
# PS4        2562189  Call of Duty: Black Ops 3Grand Theft Auto VFIF...
# PSP       12615047  Grand Theft Auto: Liberty City StoriesMonster ...
# PSV        4732241  MinecraftUncharted: Golden AbyssCall of Duty B...
# SAT        1614771  Virtua Fighter 2Sega Rally ChampionshipVirtua ...
# SCD          61031  Sonic CDShining Force CDFormula One World Cham...
# SNES       1516804  Super Mario WorldSuper Mario All-StarsDonkey K...
# TG16         24763           DoukyuuseiGinga Fukei Densetsu: Sapphire
# WS           47273  Final FantasyDigimon Adventure: Anode TamerFin...
# Wii       10243276  Wii SportsMario Kart WiiWii Sports ResortWii P...
# WiiU       1109142  Mario Kart 8New Super Mario Bros. USuper Smash...
# X360       8466048  Kinect Adventures!Grand Theft Auto VCall of Du...
# XB         7219276  Halo 2Halo: Combat EvolvedTom Clancy's Splinte...
# XOne       1575574  Call of Duty: Black Ops 3Call of Duty: Advance...
#
#                Year                                              Genre  \
# Platform
# 2600       229928.0  PuzzlePlatformShooterShooterShooterActionShoot...
# 3DO          5984.0                          AdventurePuzzleSimulation
# 3DS       1006531.0  Role-PlayingRacingRole-PlayingPlatformPlatform...
# DC         103997.0  PlatformRacingSportsAdventureActionSportsSimul...
# DS        4283493.0  PlatformSimulationRacingMiscRole-PlayingRole-P...
# GB         193608.0  Role-PlayingPuzzleRole-PlayingPlatformRole-Pla...
# GBA       1624604.0  Role-PlayingRole-PlayingRole-PlayingPlatformRa...
# GC        1085843.0  FightingRacingPlatformActionActionSimulationSh...
# GEN         53812.0  PlatformPlatformFightingActionSportsPlatformPl...
# GG           1992.0                                           Platform
# N64        631536.0  PlatformRacingShooterActionFightingStrategyPla...
# NES        194741.0  PlatformShooterPlatformPlatformActionPuzzlePuz...
# NG          23934.0  FightingFightingFightingFightingFightingFighti...
# PC        1894273.0  SimulationRole-PlayingRole-PlayingSimulationSt...
# PCFX         1996.0                                       Role-Playing
# PS        2375627.0  RacingRole-PlayingRacingRole-PlayingPlatformFi...
# PS2       4263750.0  ActionActionRacingActionRacingRole-PlayingRaci...
# PS3       2622109.0  ActionShooterShooterShooterRacingShooterAction...
# PS4        677042.0  ShooterActionSportsShooterShooterRole-PlayingS...
# PSP       2404440.0  ActionRole-PlayingActionRole-PlayingPlatformPl...
# PSV        829782.0  MiscShooterActionActionPlatformRole-PlayingRac...
# SAT        345313.0  FightingRacingFightingShooterFightingPuzzleRac...
# SCD         11963.0         PlatformStrategyRacingRole-PlayingMiscMisc
# SNES       476529.0  PlatformPlatformPlatformRacingFightingPlatform...
# TG16         3990.0                                   AdventureShooter
# WS          12000.0  Role-PlayingRole-PlayingRole-PlayingRole-Playi...
# Wii       2591562.0  SportsRacingSportsMiscPlatformSportsSportsFigh...
# WiiU       287944.0  RacingPlatformFightingShooterMiscPlatformPlatf...
# X360      2482205.0  MiscActionShooterShooterShooterShooterShooterA...
# XB        1608920.0  ShooterShooterActionRole-PlayingRole-PlayingAc...
# XOne       429150.0  ShooterShooterActionShooterRole-PlayingShooter...
#
#                                                   Publisher  NA_Sales  \
# Platform
# 2600      AtariActivisionAtariAtariAtariParker Bros.Imag...     90.60
# 3DO       Konami Digital EntertainmentMicro CabinImageworks      0.00
# 3DS       NintendoNintendoNintendoNintendoNintendoNinten...     78.87
# DC        SegaSegaSegaSegaEidos InteractiveSegaSegaSegaS...      5.43
# DS        NintendoNintendoNintendoNintendoNintendoNinten...    390.71
# GB        NintendoNintendoNintendoNintendoNintendoNinten...    114.32
# GBA       NintendoNintendoNintendoNintendoNintendoNinten...    187.54
# GC        NintendoNintendoNintendoNintendoNintendoNinten...    133.46
# GEN       SegaSegaArena EntertainmentSegaArena Entertain...     19.27
# GG                                                     Sega      0.00
# N64       NintendoNintendoNintendoNintendoNintendoNinten...    139.02
# NES       NintendoNintendoNintendoNintendoNintendoNinten...    125.94
# NG        SNKSNKSNKSNKSNKSNKSNKSNKSNKSNKHudson SoftTechn...      0.00
# PC        Electronic ArtsActivisionActivisionMicrosoft G...     93.28
# PCFX                                                    NEC      0.00
# PS        Sony Computer EntertainmentSony Computer Enter...    336.51
# PS2       Take-Two InteractiveTake-Two InteractiveSony C...    583.84
# PS3       Take-Two InteractiveActivisionActivisionActivi...    392.26
# PS4       ActivisionTake-Two InteractiveElectronic ArtsE...     96.80
# PSP       Take-Two InteractiveCapcomTake-Two Interactive...    108.99
# PSV       Sony Computer Entertainment EuropeSony Compute...     16.20
# SAT       SegaSegaSegaSegaSegaCompileSegaSegaBanprestoBa...      0.72
# SCD                                SegaSegaSegaSegaSegaSega      1.00
# SNES      NintendoNintendoNintendoNintendoCapcomNintendo...     61.23
# TG16                                         NECHudson Soft      0.00
# WS        SquareSoftNamco Bandai GamesSquareSoftNamco Ba...      0.00
# Wii       NintendoNintendoNintendoNintendoNintendoNinten...    507.71
# WiiU      NintendoNintendoNintendoNintendoNintendoNinten...     38.32
# X360      Microsoft Game StudiosTake-Two InteractiveActi...    601.05
# XB        Microsoft Game StudiosMicrosoft Game StudiosUb...    186.69
# XOne      ActivisionActivisionTake-Two InteractiveMicros...     83.19
#
#           EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# 2600          5.47      0.00         0.91         97.08
# 3DO           0.00      0.10         0.00          0.10
# 3DS          58.52     97.35        12.63        247.46
# DC            1.69      8.56         0.27         15.97
# DS          194.65    175.57        60.53        822.49
# GB           47.82     85.12         8.20        255.45
# GBA          75.25     47.33         7.73        318.50
# GC           38.71     21.58         5.18        199.36
# GEN           5.52      2.67         0.89         28.36
# GG            0.00      0.04         0.00          0.04
# N64          41.06     34.22         4.38        218.88
# NES          21.15     98.65         5.31        251.07
# NG            0.00      1.44         0.00          1.44
# PC          139.68      0.17        24.86        258.82
# PCFX          0.00      0.03         0.00          0.03
# PS          213.60    139.82        40.91        730.66
# PS2         339.29    139.20       193.44       1255.64
# PS3         343.71     79.99       141.93        957.84
# PS4         123.70     14.30        43.36        278.10
# PSP          68.25     76.79        42.19        296.28
# PSV          16.33     20.96         8.45         61.93
# SAT           0.54     32.26         0.07         33.59
# SCD           0.36      0.45         0.05          1.87
# SNES         19.04    116.55         3.22        200.05
# TG16          0.00      0.16         0.00          0.16
# WS            0.00      1.42         0.00          1.42
# Wii         268.38     69.35        80.61        926.71
# WiiU         24.23     12.79         6.45         81.86
# X360        280.58     12.43        85.54        979.96
# XB           60.95      1.38         8.72        258.26
# XOne         45.65      0.34        11.92        141.06

# %% [markdown]
# <p>Aggregating functions are the ones that reduce the dimension of the returned objects.
# Some common aggregating functions are tabulated below:</p>
# <table class="colwidths-given table">
# <colgroup>
# <col style="width: 20%">
# <col style="width: 80%">
# </colgroup>
# <thead>
# <tr class="row-odd"><th class="head"><p>Function</p></th>
# <th class="head"><p>Description</p></th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">mean()</span></code></p></td>
# <td><p>Compute mean of groups</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">sum()</span></code></p></td>
# <td><p>Compute sum of group values</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">size()</span></code></p></td>
# <td><p>Compute group sizes</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">count()</span></code></p></td>
# <td><p>Compute count of group</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">std()</span></code></p></td>
# <td><p>Standard deviation of groups</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">var()</span></code></p></td>
# <td><p>Compute variance of groups</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">sem()</span></code></p></td>
# <td><p>Standard error of the mean of groups</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">describe()</span></code></p></td>
# <td><p>Generates descriptive statistics</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">first()</span></code></p></td>
# <td><p>Compute first of group values</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">last()</span></code></p></td>
# <td><p>Compute last of group values</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">nth()</span></code></p></td>
# <td><p>Take nth value, or a subset if n is a list</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">min()</span></code></p></td>
# <td><p>Compute min of group values</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">max()</span></code></p></td>
# <td><p>Compute max of group values</p></td>
# </tr>
# </tbody>
# </table>

# %%
data.groupby('Platform')[['NA_Sales','Global_Sales']]. \
aggregate([np.sum,np.max,np.min])
# Out:
# C:\Users\Clement\AppData\Local\Temp\ipykernel_15756\2047903110.py:2: FutureWarning: The provided callable <function sum at 0x000002CDFF684B80> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   aggregate([np.sum,np.max,np.min])
# C:\Users\Clement\AppData\Local\Temp\ipykernel_15756\2047903110.py:2: FutureWarning: The provided callable <function max at 0x000002CDFF685580> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   aggregate([np.sum,np.max,np.min])
# C:\Users\Clement\AppData\Local\Temp\ipykernel_15756\2047903110.py:2: FutureWarning: The provided callable <function min at 0x000002CDFF6856C0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   aggregate([np.sum,np.max,np.min])
# C:\Users\Clement\AppData\Local\Temp\ipykernel_15756\2047903110.py:2: FutureWarning: The provided callable <function sum at 0x000002CDFF684B80> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   aggregate([np.sum,np.max,np.min])
#          NA_Sales              Global_Sales
#               sum    max   min          sum    max   min
# Platform
# 2600        90.60   7.28  0.07        97.08   7.81  0.07
# 3DO          0.00   0.00  0.00         0.10   0.06  0.02
# 3DS         78.87   5.17  0.00       247.46  14.35  0.01
# DC           5.43   1.26  0.00        15.97   2.42  0.02
# DS         390.71  11.38  0.00       822.49  30.01  0.01
# GB         114.32  23.20  0.00       255.45  31.37  0.06
# GBA        187.54   6.06  0.00       318.50  15.85  0.01
# GC         133.46   4.41  0.00       199.36   7.07  0.01
# GEN         19.27   4.47  0.00        28.36   6.03  0.03
# GG           0.00   0.00  0.00         0.04   0.04  0.04
# N64        139.02   6.91  0.00       218.88  11.89  0.01
# NES        125.94  29.08  0.00       251.07  40.24  0.06
# NG           0.00   0.00  0.00         1.44   0.25  0.02
# PC          93.28   4.03  0.00       258.82   8.11  0.01
# PCFX         0.00   0.00  0.00         0.03   0.03  0.03
# PS         336.51   4.02  0.00       730.66  10.95  0.01
# PS2        583.84   9.43  0.00      1255.64  20.81  0.01
# PS3        392.26   7.01  0.00       957.84  21.40  0.01
# PS4         96.80   5.77  0.00       278.10  14.24  0.01
# PSP        108.99   2.90  0.00       296.28   7.72  0.01
# PSV         16.20   0.80  0.00        61.93   2.25  0.01
# SAT          0.72   0.34  0.00        33.59   1.93  0.02
# SCD          1.00   1.00  0.00         1.87   1.50  0.05
# SNES        61.23  12.78  0.00       200.05  20.61  0.01
# TG16         0.00   0.00  0.00         0.16   0.14  0.02
# WS           0.00   0.00  0.00         1.42   0.51  0.03
# Wii        507.71  41.49  0.00       926.71  82.74  0.01
# WiiU        38.32   3.13  0.00        81.86   6.96  0.01
# X360       601.05  14.97  0.00       979.96  21.82  0.01
# XB         186.69   6.82  0.00       258.26   8.49  0.01
# XOne        83.19   4.52  0.00       141.06   7.30  0.01

# %%
data.groupby('Platform')[['NA_Sales','Global_Sales']].aggregate(
    [lambda x: x.max() - x.min(),
    lambda x: x.median() - x.mean()]
)
# Out:
#            NA_Sales            Global_Sales
#          <lambda_0> <lambda_1>   <lambda_0> <lambda_1>
# Platform
# 2600           7.21  -0.251203         7.74  -0.269925
# 3DO            0.00   0.000000         0.04  -0.013333
# 3DS            5.17  -0.144951        14.34  -0.366169
# DC             1.26  -0.104423         2.40  -0.172115
# DS            11.38  -0.120633        30.00  -0.270254
# GB            23.20  -1.166531        31.31  -1.441633
# GBA            6.06  -0.128151        15.84  -0.222470
# GC             4.41  -0.130036         7.06  -0.208561
# GEN            4.47  -0.713704         6.00  -0.900370
# GG             0.00   0.000000         0.00   0.000000
# N64            6.91  -0.255799        11.88  -0.416144
# NES           29.08  -0.880102        40.18  -1.186939
# NG             0.00   0.000000         0.23  -0.020000
# PC             4.03  -0.097167         8.10  -0.229604
# PCFX           0.00   0.000000         0.00   0.000000
# PS             4.02  -0.201363        10.94  -0.350920
# PS2            9.43  -0.180171        20.80  -0.351046
# PS3            7.01  -0.175154        21.39  -0.440722
# PS4            5.77  -0.218095        14.23  -0.607679
# PSP            2.90  -0.089852         7.71  -0.154254
# PSV            0.80  -0.039225         2.24  -0.089952
# SAT            0.34  -0.004162         1.91  -0.074162
# SCD            1.00  -0.166667         1.45  -0.246667
# SNES          12.78  -0.256192        20.60  -0.517029
# TG16           0.00   0.000000         0.12   0.000000
# WS             0.00   0.000000         0.48  -0.021667
# Wii           41.49  -0.243177        82.73  -0.499404
# WiiU           3.13  -0.147972         6.95  -0.342448
# X360          14.97  -0.305138        21.81  -0.494672
# XB             6.82  -0.116566         8.48  -0.173422
# XOne           4.52  -0.240563         7.29  -0.422254

# %%
def A1(x):
    return np.max(x) - np.min(x)
def B2(x):
    return np.median(x) - np.mean(x)
data.groupby('Platform')[['NA_Sales','Global_Sales']].aggregate(
    [A1,B2]
)
# Out:
#          NA_Sales           Global_Sales
#                A1        B2           A1        B2
# Platform
# 2600         7.21 -0.251203         7.74 -0.269925
# 3DO          0.00  0.000000         0.04 -0.013333
# 3DS          5.17 -0.144951        14.34 -0.366169
# DC           1.26 -0.104423         2.40 -0.172115
# DS          11.38 -0.120633        30.00 -0.270254
# GB          23.20 -1.166531        31.31 -1.441633
# GBA          6.06 -0.128151        15.84 -0.222470
# GC           4.41 -0.130036         7.06 -0.208561
# GEN          4.47 -0.713704         6.00 -0.900370
# GG           0.00  0.000000         0.00  0.000000
# N64          6.91 -0.255799        11.88 -0.416144
# NES         29.08 -0.880102        40.18 -1.186939
# NG           0.00  0.000000         0.23 -0.020000
# PC           4.03 -0.097167         8.10 -0.229604
# PCFX         0.00  0.000000         0.00  0.000000
# PS           4.02 -0.201363        10.94 -0.350920
# PS2          9.43 -0.180171        20.80 -0.351046
# PS3          7.01 -0.175154        21.39 -0.440722
# PS4          5.77 -0.218095        14.23 -0.607679
# PSP          2.90 -0.089852         7.71 -0.154254
# PSV          0.80 -0.039225         2.24 -0.089952
# SAT          0.34 -0.004162         1.91 -0.074162
# SCD          1.00 -0.166667         1.45 -0.246667
# SNES        12.78 -0.256192        20.60 -0.517029
# TG16         0.00  0.000000         0.12  0.000000
# WS           0.00  0.000000         0.48 -0.021667
# Wii         41.49 -0.243177        82.73 -0.499404
# WiiU         3.13 -0.147972         6.95 -0.342448
# X360        14.97 -0.305138        21.81 -0.494672
# XB           6.82 -0.116566         8.48 -0.173422
# XOne         4.52 -0.240563         7.29 -0.422254

# %% [markdown]
# ## Transform

# %%
data.groupby('Platform')['Global_Sales'].transform(sum)
# Out:
# C:\Users\Clement\AppData\Local\Temp\ipykernel_15756\1971001776.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   data.groupby('Platform')['Global_Sales'].transform(sum)
# 0         926.71
# 1         251.07
# 2         926.71
# 3         926.71
# 4         255.45
#           ...
# 16593     318.50
# 16594     199.36
# 16595    1255.64
# 16596     822.49
# 16597     318.50
# Name: Global_Sales, Length: 16598, dtype: float64

# %%
data.groupby('Platform')['Global_Sales'].aggregate(np.sum)
# Out:
# C:\Users\Clement\AppData\Local\Temp\ipykernel_15756\1118599000.py:1: FutureWarning: The provided callable <function sum at 0x000002CDFF684B80> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   data.groupby('Platform')['Global_Sales'].aggregate(np.sum)
# Platform
# 2600      97.08
# 3DO        0.10
# 3DS      247.46
# DC        15.97
# DS       822.49
# GB       255.45
# GBA      318.50
# GC       199.36
# GEN       28.36
# GG         0.04
# N64      218.88
# NES      251.07
# NG         1.44
# PC       258.82
# PCFX       0.03
# PS       730.66
# PS2     1255.64
# PS3      957.84
# PS4      278.10
# PSP      296.28
# PSV       61.93
# SAT       33.59
# SCD        1.87
# SNES     200.05
# TG16       0.16
# WS         1.42
# Wii      926.71
# WiiU      81.86
# X360     979.96
# XB       258.26
# XOne     141.06
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ## apply

# %%
data2 = data.copy()
global_sum = data2.groupby('Platform')['Global_Sales'].transform(np.sum)
data2['銷售佔比'] = data2['Global_Sales'] / global_sum
data2
# Out:
# C:\Users\Clement\AppData\Local\Temp\ipykernel_15756\3159480719.py:2: FutureWarning: The provided callable <function sum at 0x000002CDFF684B80> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   global_sum = data2.groupby('Platform')['Global_Sales'].transform(np.sum)
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales      銷售佔比
# 0             8.46         82.74  0.089284
# 1             0.77         40.24  0.160274
# 2             3.31         35.82  0.038653
# 3             2.96         33.00  0.035610
# 4             1.00         31.37  0.122803
# ...            ...           ...       ...
# 16593         0.00          0.01  0.000031
# 16594         0.00          0.01  0.000050
# 16595         0.00          0.01  0.000008
# 16596         0.00          0.01  0.000012
# 16597         0.00          0.01  0.000031
#
# [16598 rows x 12 columns]

# %%
#使用apply來達成等同上面的功能
def rate(x):
    x['銷售佔比'] = x['Global_Sales'] / x['Global_Sales'].sum()
    return x
data2 = data.copy()
data2.groupby('Platform').apply(rate)
# Out:
# C:\Users\Clement\AppData\Local\Temp\ipykernel_15756\1485670978.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data2.groupby('Platform').apply(rate)
#                  Rank                      Name Platform    Year     Genre  \
# Platform
# 2600     89        90                   Pac-Man     2600  1982.0    Puzzle
#          239      240                  Pitfall!     2600  1981.0  Platform
#          258      259                 Asteroids     2600  1980.0   Shooter
#          544      545           Missile Command     2600  1980.0   Shooter
#          607      608            Space Invaders     2600     NaN   Shooter
# ...               ...                       ...      ...     ...       ...
# XOne     16530  16533  Sébastien Loeb Rally Evo     XOne  2016.0    Racing
#          16531  16534             Hitman (2016)     XOne  2016.0    Action
#          16562  16565              Mighty No. 9     XOne  2016.0  Platform
#          16569  16572        Resident Evil 4 HD     XOne  2016.0   Shooter
#          16576  16579         Rugby Challenge 3     XOne  2016.0    Sports
#
#                            Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# 2600     89                    Atari      7.28      0.45       0.0
#          239              Activision      4.21      0.24       0.0
#          258                   Atari      4.00      0.26       0.0
#          544                   Atari      2.56      0.17       0.0
#          607                   Atari      2.36      0.14       0.0
# ...                              ...       ...       ...       ...
# XOne     16530       Milestone S.r.l      0.00      0.01       0.0
#          16531           Square Enix      0.00      0.01       0.0
#          16562           Deep Silver      0.01      0.00       0.0
#          16569                Capcom      0.01      0.00       0.0
#          16576  Alternative Software      0.00      0.01       0.0
#
#                 Other_Sales  Global_Sales      銷售佔比
# Platform
# 2600     89            0.08          7.81  0.080449
#          239           0.05          4.50  0.046354
#          258           0.05          4.31  0.044396
#          544           0.03          2.76  0.028430
#          607           0.03          2.53  0.026061
# ...                     ...           ...       ...
# XOne     16530         0.00          0.01  0.000071
#          16531         0.00          0.01  0.000071
#          16562         0.00          0.01  0.000071
#          16569         0.00          0.01  0.000071
#          16576         0.00          0.01  0.000071
#
# [16598 rows x 12 columns]

# %% [markdown]
# ## filter

# %%
# 列出該平台總銷售額大於 1000 百萬的遊戲
index = data.groupby('Platform')['Global_Sales'].transform(sum) > 1000
data[index]
# Out:
# C:\Users\Clement\AppData\Local\Temp\ipykernel_15756\3551512799.py:2: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   index = data.groupby('Platform')['Global_Sales'].transform(sum) > 1000
#         Rank                                              Name Platform  \
# 17        18                     Grand Theft Auto: San Andreas      PS2
# 24        25                       Grand Theft Auto: Vice City      PS2
# 28        29                            Gran Turismo 3: A-Spec      PS2
# 38        39                              Grand Theft Auto III      PS2
# 47        48                                    Gran Turismo 4      PS2
# ...      ...                                               ...      ...
# 16559  16562      Sugar + Spice! Anoko no Suteki na Nanimokamo      PS2
# 16561  16564                                    Kanokon: Esuii      PS2
# 16572  16575                  Scarlett: Nichijou no Kyoukaisen      PS2
# 16580  16583                                         Real Rode      PS2
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
#
#          Year      Genre                    Publisher  NA_Sales  EU_Sales  \
# 17     2004.0     Action         Take-Two Interactive      9.43      0.40
# 24     2002.0     Action         Take-Two Interactive      8.41      5.49
# 28     2001.0     Racing  Sony Computer Entertainment      6.85      5.09
# 38     2001.0     Action         Take-Two Interactive      6.99      4.51
# 47     2004.0     Racing  Sony Computer Entertainment      3.01      0.01
# ...       ...        ...                          ...       ...       ...
# 16559  2008.0  Adventure                    Alchemist      0.00      0.00
# 16561  2008.0  Adventure                          5pb      0.00      0.00
# 16572  2008.0  Adventure              Kadokawa Shoten      0.00      0.00
# 16580  2008.0  Adventure              Kadokawa Shoten      0.00      0.00
# 16595  2008.0     Racing                   Activision      0.00      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 17         0.41        10.57         20.81
# 24         0.47         1.78         16.15
# 28         1.87         1.16         14.98
# 38         0.30         1.30         13.10
# 47         1.10         7.53         11.66
# ...         ...          ...           ...
# 16559      0.01         0.00          0.01
# 16561      0.01         0.00          0.01
# 16572      0.01         0.00          0.01
# 16580      0.01         0.00          0.01
# 16595      0.00         0.00          0.01
#
# [2161 rows x 11 columns]

# %%
# 列出所有PS平台的遊戲
def AAA(x):
    slist = ['PS','PS2','PS3']
    return any(x.iloc[0]['Platform'] in s for s in slist)
data.groupby('Platform').filter(AAA)
# Out:
#         Rank                                              Name Platform  \
# 16        17                                Grand Theft Auto V      PS3
# 17        18                     Grand Theft Auto: San Andreas      PS2
# 24        25                       Grand Theft Auto: Vice City      PS2
# 28        29                            Gran Turismo 3: A-Spec      PS2
# 34        35                        Call of Duty: Black Ops II      PS3
# ...      ...                                               ...      ...
# 16559  16562      Sugar + Spice! Anoko no Suteki na Nanimokamo      PS2
# 16561  16564                                    Kanokon: Esuii      PS2
# 16572  16575                  Scarlett: Nichijou no Kyoukaisen      PS2
# 16580  16583                                         Real Rode      PS2
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
#
#          Year      Genre                    Publisher  NA_Sales  EU_Sales  \
# 16     2013.0     Action         Take-Two Interactive      7.01      9.27
# 17     2004.0     Action         Take-Two Interactive      9.43      0.40
# 24     2002.0     Action         Take-Two Interactive      8.41      5.49
# 28     2001.0     Racing  Sony Computer Entertainment      6.85      5.09
# 34     2012.0    Shooter                   Activision      4.99      5.88
# ...       ...        ...                          ...       ...       ...
# 16559  2008.0  Adventure                    Alchemist      0.00      0.00
# 16561  2008.0  Adventure                          5pb      0.00      0.00
# 16572  2008.0  Adventure              Kadokawa Shoten      0.00      0.00
# 16580  2008.0  Adventure              Kadokawa Shoten      0.00      0.00
# 16595  2008.0     Racing                   Activision      0.00      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 16         0.97         4.14         21.40
# 17         0.41        10.57         20.81
# 24         0.47         1.78         16.15
# 28         1.87         1.16         14.98
# 34         0.65         2.52         14.03
# ...         ...          ...           ...
# 16559      0.01         0.00          0.01
# 16561      0.01         0.00          0.01
# 16572      0.01         0.00          0.01
# 16580      0.01         0.00          0.01
# 16595      0.00         0.00          0.01
#
# [4686 rows x 11 columns]
